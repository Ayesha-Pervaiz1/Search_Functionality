# %%
# %pip install google-cloud-vision
# Out:
# ...
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
# ...

# %%
# import os

# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "D:/Techionik_2025/Search_functionality/searchfunctionality-edfb27248b0e.json"

# %%
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-755a32cacaed.json"

# %%
# # This jason api not working as I make it from my own account and its not billing account.
# from google.cloud import vision
# import io

# # Initialize the Vision API client
# client = vision.ImageAnnotatorClient()

# # Path to the image you want to analyze
# image_path = r"D:\Techionik_2025\Search_functionality\Images\image_13.jpg"  # Use raw string for the path

# # Read the image file
# with io.open(image_path, 'rb') as image_file:
#     content = image_file.read()

# # Create an Image object
# image = vision.Image(content=content)

# # Perform label detection on the image
# response = client.label_detection(image=image)
# labels = response.label_annotations

# # Print the labels detected in the image
# print("Labels:")
# for label in labels:
#     print(label.description)

# %%
# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Used another method to make api from credentials rather than service credential jason  --This is also not working as account is not billing 
API_KEY = os.getenv("AIzaSyDwGve6Cp_Z4m6lM7t9pdqrc7mNavYvtbQ")

# %%
import requests
import base64
import json

# Replace with your actual API key
API_KEY = "AIzaSyBFMXfAz9O6sy8IOMTJhkl4qK4R6Xuux2Y"  

# Path to the image you want to analyze
image_path = r"D:\Techionik_2025\Search_functionality\Images\image_13.jpg"  # Use raw string for the path

# Read and encode the image in base64
with open(image_path, "rb") as image_file:
    encoded_image = base64.b64encode(image_file.read()).decode("utf-8")

# Google Vision API endpoint
url = f"https://vision.googleapis.com/v1/images:annotate?key={API_KEY}"

# Request payload
payload = {
    "requests": [
        {
            "image": {"content": encoded_image},
            "features": [{"type": "LABEL_DETECTION", "maxResults": 5}],  # Detects objects in the image
        }
    ]
}

# Send POST request
response = requests.post(url, json=payload)

# Parse and display the response
if response.status_code == 200:
    result = response.json()
    print("Labels detected:")
    for label in result["responses"][0]["labelAnnotations"]:
        print(f"- {label['description']} (Confidence: {label['score']:.2f})")
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# Labels detected:
# - Engagement ring (Confidence: 0.91)
# - Gemstone (Confidence: 0.87)
# - Diamond (Confidence: 0.83)
# - Natural material (Confidence: 0.79)
# - Pre-engagement ring (Confidence: 0.75)

# %%
# %pip install google-cloud-vision google-search-python openpyxl requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement google-search-python (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for google-search-python

# %%
#Store Image url in excel
import os
import requests
import openpyxl
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

def create_excel(file_path):
    """Creates an Excel file with gem carat metadata in Column A."""
    wb = openpyxl.Workbook()
    sheet = wb.active
    sheet.title = "Gem Carat Data"
    
    # Adding headers
    sheet.cell(row=1, column=1, value="Gem Carat")
    sheet.cell(row=1, column=2, value="Image URL")
    sheet.cell(row=1, column=3, value="Vision API Labels")
    
    # Gem Carat metadata
    gem_carat_values = [
        "Under 1 Carat", "0.5 Carat", "1 Carat", "2 Carat", "2.5 Carat", "3 Carat",
        "4 Carat", "5 Carat", "6 Carat", "7 Carat", "8 Carat", "9 Carat", "10 Carat",
        "- 0.25 Carat Each Side Stone", "- Approx 0.25 Carat Smalls", "- Approx 0.5 Carat Smalls",
        "- Approx 0.75 Carat Smalls", "- Approx 1 Carat Smalls", "- Approx 2 Carat Smalls"
    ]
    
    # Inserting data into the sheet
    for idx, value in enumerate(gem_carat_values, start=2):
        sheet.cell(row=idx, column=1, value=value)
    
    # Save the Excel file
    wb.save(file_path)
    print(f"✅ Excel file created successfully: {file_path}")

def search_image(query, api_key, cse_id):
    """Search for an image using Google Custom Search JSON API."""
    try:
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(q=query, cx=cse_id, searchType="image", num=1).execute()
        if "items" in res:
            return res["items"][0]["link"]
    except HttpError as e:
        print(f"❌ Google Search API Error: {e}")
    return None

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description for label in response.label_annotations]
        return ", ".join(labels)
    except Exception as e:
        print(f"❌ Vision API Error: {e}")
        return "Error in image analysis"

def update_excel_with_images(file_path, api_key, cse_id):
    """Fetch images for metadata, analyze them with Vision API, and update Excel file."""
    wb = openpyxl.load_workbook(file_path)
    sheet = wb.active

    for row in range(2, sheet.max_row + 1):
        metadata = sheet.cell(row, 1).value
        if metadata:
            existing_image_url = sheet.cell(row, 2).value
            if not existing_image_url:  # Avoid re-fetching images if already present
                print(f"🔍 Searching image for: {metadata}")
                image_url = search_image(metadata, api_key, cse_id)
                if image_url:
                    labels = analyze_image(image_url)
                    sheet.cell(row, 2).value = image_url  # Store image URL in Column B
                    sheet.cell(row, 3).value = labels  # Store Vision API labels in Column C
                else:
                    print(f"⚠ No image found for {metadata}")
    
    wb.save(file_path)
    print("✅ Excel updated with image URLs and Vision API labels successfully!")

# 🔹 Google API credentials
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# 🔹 Fix the file path issue
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json"  

EXCEL_FILE = "gem_carat_data.xlsx"

# 🔹 Run the functions
create_excel(EXCEL_FILE)
update_excel_with_images(EXCEL_FILE, API_KEY, CSE_ID)
# Out:
# ✅ Excel file created successfully: gem_carat_data.xlsx
# 🔍 Searching image for: Under 1 Carat
# 🔍 Searching image for: 0.5 Carat
# 🔍 Searching image for: 1 Carat
# 🔍 Searching image for: 2 Carat
# 🔍 Searching image for: 2.5 Carat
# 🔍 Searching image for: 3 Carat
# 🔍 Searching image for: 4 Carat
# 🔍 Searching image for: 5 Carat
# 🔍 Searching image for: 6 Carat
# 🔍 Searching image for: 7 Carat
# 🔍 Searching image for: 8 Carat
# 🔍 Searching image for: 9 Carat
# 🔍 Searching image for: 10 Carat
# 🔍 Searching image for: - 0.25 Carat Each Side Stone
# 🔍 Searching image for: - Approx 0.25 Carat Smalls
# 🔍 Searching image for: - Approx 0.5 Carat Smalls
# 🔍 Searching image for: - Approx 0.75 Carat Smalls
# 🔍 Searching image for: - Approx 1 Carat Smalls
# 🔍 Searching image for: - Approx 2 Carat Smalls
# ✅ Excel updated with image URLs and Vision API labels successfully!

# %%
#Download images locally and Store image path in excel as well 
import os
import requests
import openpyxl
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# 🔹 Ensure the image storage directory exists
IMAGE_DIR = "downloaded_images"
os.makedirs(IMAGE_DIR, exist_ok=True)

def create_excel(file_path):
    """Creates an Excel file with gem carat metadata in Column A."""
    wb = openpyxl.Workbook()
    sheet = wb.active
    sheet.title = "Gem Carat Data"
    
    # Adding headers
    sheet.cell(row=1, column=1, value="Gem Carat")
    sheet.cell(row=1, column=2, value="Image URL")
    sheet.cell(row=1, column=3, value="Vision API Labels")
    sheet.cell(row=1, column=4, value="Image Path")  # New column for local image path
    
    # Gem Carat metadata
    gem_carat_values = [
        "Under 1 Carat", "0.5 Carat", "1 Carat", "2 Carat", "2.5 Carat", "3 Carat",
        "4 Carat", "5 Carat", "6 Carat", "7 Carat", "8 Carat", "9 Carat", "10 Carat",
        "- 0.25 Carat Each Side Stone", "- Approx 0.25 Carat Smalls", "- Approx 0.5 Carat Smalls",
        "- Approx 0.75 Carat Smalls", "- Approx 1 Carat Smalls", "- Approx 2 Carat Smalls"
    ]
    
    # Inserting data into the sheet
    for idx, value in enumerate(gem_carat_values, start=2):
        sheet.cell(row=idx, column=1, value=value)
    
    # Save the Excel file
    wb.save(file_path)
    print(f"✅ Excel file created successfully: {file_path}")

def search_image(query, api_key, cse_id):
    """Search for an image using Google Custom Search JSON API."""
    try:
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(q=query, cx=cse_id, searchType="image", num=1).execute()
        if "items" in res:
            return res["items"][0]["link"]
    except HttpError as e:
        print(f"❌ Google Search API Error: {e}")
    return None

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description for label in response.label_annotations]
        return ", ".join(labels)
    except Exception as e:
        print(f"❌ Vision API Error: {e}")
        return "Error in image analysis"

def download_image(image_url, filename):
    """Download and save an image from a URL."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img_path = os.path.join(IMAGE_DIR, filename)
            img.save(img_path)
            return img_path
    except Exception as e:
        print(f"❌ Error downloading image: {e}")
    return None

def update_excel_with_images(file_path, api_key, cse_id):
    """Fetch images, analyze with Vision API, download, and update Excel."""
    wb = openpyxl.load_workbook(file_path)
    sheet = wb.active

    for row in range(2, sheet.max_row + 1):
        metadata = sheet.cell(row, 1).value
        if metadata:
            existing_image_url = sheet.cell(row, 2).value
            if not existing_image_url:  # Avoid re-fetching images if already present
                print(f"🔍 Searching image for: {metadata}")
                image_url = search_image(metadata, api_key, cse_id)
                if image_url:
                    labels = analyze_image(image_url)
                    image_filename = f"{metadata.replace(' ', '_')}.jpg"
                    image_path = download_image(image_url, image_filename)

                    # Store results in Excel
                    sheet.cell(row, 2, value=image_url)  # Column B: Image URL
                    sheet.cell(row, 3, value=labels)  # Column C: Vision API Labels
                    sheet.cell(row, 4, value=image_path)  # Column D: Local Image Path
                    
                    print(f"✅ Image saved: {image_path}")
                else:
                    print(f"⚠ No image found for {metadata}")
    
    wb.save(file_path)
    print("✅ Excel updated with image URLs, Vision API labels, and local image paths!")

# 🔹 Google API credentials
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# 🔹 Fix the file path issue
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json"  

EXCEL_FILE = "gem_carat_data_withImages.xlsx"

# 🔹 Run the functions
create_excel(EXCEL_FILE)
update_excel_with_images(EXCEL_FILE, API_KEY, CSE_ID)
# Out:
# ✅ Excel file created successfully: gem_carat_data_withImages.xlsx
# 🔍 Searching image for: Under 1 Carat
# ✅ Image saved: downloaded_images\Under_1_Carat.jpg
# 🔍 Searching image for: 0.5 Carat
# ✅ Image saved: downloaded_images\0.5_Carat.jpg
# 🔍 Searching image for: 1 Carat
# ✅ Image saved: None
# 🔍 Searching image for: 2 Carat
# ✅ Image saved: downloaded_images\2_Carat.jpg
# 🔍 Searching image for: 2.5 Carat
# ✅ Image saved: downloaded_images\2.5_Carat.jpg
# 🔍 Searching image for: 3 Carat
# ✅ Image saved: downloaded_images\3_Carat.jpg
# 🔍 Searching image for: 4 Carat
# ✅ Image saved: downloaded_images\4_Carat.jpg
# 🔍 Searching image for: 5 Carat
# ✅ Image saved: downloaded_images\5_Carat.jpg
# 🔍 Searching image for: 6 Carat
# ✅ Image saved: downloaded_images\6_Carat.jpg
# 🔍 Searching image for: 7 Carat
# ✅ Image saved: downloaded_images\7_Carat.jpg
# 🔍 Searching image for: 8 Carat
# ✅ Image saved: downloaded_images\8_Carat.jpg
# 🔍 Searching image for: 9 Carat
# ...

# %%
#Filter ER and carat and store images in excel 
import os
import requests
import openpyxl
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# 🔹 Ensure the image storage directory exists
IMAGE_DIR = "Engagement_rings"
os.makedirs(IMAGE_DIR, exist_ok=True)

def create_excel(file_path):
    """Creates an Excel file with gem carat metadata in Column A."""
    wb = openpyxl.Workbook()
    sheet = wb.active
    sheet.title = "EngagementRing"
    
    # Adding headers
    sheet.cell(row=1, column=1, value="Gem Carat")
    sheet.cell(row=1, column=2, value="Image URL")
    sheet.cell(row=1, column=3, value="Vision API Labels")
    sheet.cell(row=1, column=4, value="Embedded Image")  # New column for embedded image
    
    # Gem Carat metadata
    gem_carat_values = [
        "Under 1 Carat", "0.5 Carat", "1 Carat", "2 Carat", "2.5 Carat", "3 Carat",
        "4 Carat", "5 Carat", "6 Carat", "7 Carat", "8 Carat", "9 Carat", "10 Carat",
        "- 0.25 Carat Each Side Stone", "- Approx 0.25 Carat Smalls", "- Approx 0.5 Carat Smalls",
        "- Approx 0.75 Carat Smalls", "- Approx 1 Carat Smalls", "- Approx 2 Carat Smalls"
    ]
    
    # Inserting data into the sheet
    for idx, value in enumerate(gem_carat_values, start=2):
        sheet.cell(row=idx, column=1, value=value)
    
    # Save the Excel file
    wb.save(file_path)
    print(f"✅ Excel file created successfully: {file_path}")

def search_image(query, api_key, cse_id):
    """Search for an image using Google Custom Search JSON API."""
    try:
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(q=query + " engagement ring", cx=cse_id, searchType="image", num=1).execute()
        if "items" in res:
            return res["items"][0]["link"]
    except HttpError as e:
        print(f"❌ Google Search API Error: {e}")
    return None

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"❌ Vision API Error: {e}")
        return []

def download_image(image_url):
    """Download and return image as PIL object."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            return img
    except Exception as e:
        print(f"❌ Error downloading image: {e}")
    return None

def update_excel_with_images(file_path, api_key, cse_id):
    """Fetch images, analyze with Vision API, filter for engagement rings, and embed images in Excel."""
    wb = openpyxl.load_workbook(file_path)
    sheet = wb.active

    for row in range(2, sheet.max_row + 1):
        metadata = sheet.cell(row, 1).value
        if metadata:
            existing_image_url = sheet.cell(row, 2).value
            if not existing_image_url:  # Avoid re-fetching images if already present
                print(f"🔍 Searching image for: {metadata}")
                image_url = search_image(metadata, api_key, cse_id)
                if image_url:
                    labels = analyze_image(image_url)

                    # 🔹 Filter: Ensure the image is related to engagement rings
                    if "engagement ring" in labels or "ring" in labels:
                        print(f"✅ Image matches engagement ring criteria: {metadata}")

                        image = download_image(image_url)
                        if image:
                            # Store results in Excel
                            sheet.cell(row, 2, value=image_url)  # Column B: Image URL
                            sheet.cell(row, 3, value=", ".join(labels))  # Column C: Vision API Labels

                            # Resize image to fit in the Excel cell
                            max_width = 100  # pixels
                            max_height = 100  # pixels
                            image.thumbnail((max_width, max_height))

                            # Save image temporarily
                            temp_image_path = f"{IMAGE_DIR}/{metadata.replace(' ', '_')}.png"
                            image.save(temp_image_path)

                            # Embed image in Excel
                            img = openpyxl.drawing.image.Image(temp_image_path)
                            img.anchor = sheet.cell(row=row, column=4).coordinate  # Column D: Embedded Image
                            sheet.add_image(img)
                            
                            print(f"📷 Image embedded in Excel: {metadata}")
                    else:
                        print(f"⚠ Image does NOT match engagement ring criteria: {metadata}")

    wb.save(file_path)
    print("✅ Excel updated with engagement ring images!")

# 🔹 Google API credentials
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# 🔹 Fix the file path issue
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json"  

EXCEL_FILE = "gem_carat_data_ERImage.xlsx"

# 🔹 Run the functions
create_excel(EXCEL_FILE)
update_excel_with_images(EXCEL_FILE, API_KEY, CSE_ID)
# Out:
# ✅ Excel file created successfully: gem_carat_data_ERImage.xlsx
# 🔍 Searching image for: Under 1 Carat
# ✅ Image matches engagement ring criteria: Under 1 Carat
# 📷 Image embedded in Excel: Under 1 Carat
# 🔍 Searching image for: 0.5 Carat
# ✅ Image matches engagement ring criteria: 0.5 Carat
# 📷 Image embedded in Excel: 0.5 Carat
# 🔍 Searching image for: 1 Carat
# ✅ Image matches engagement ring criteria: 1 Carat
# 🔍 Searching image for: 2 Carat
# ✅ Image matches engagement ring criteria: 2 Carat
# 📷 Image embedded in Excel: 2 Carat
# 🔍 Searching image for: 2.5 Carat
# ✅ Image matches engagement ring criteria: 2.5 Carat
# 📷 Image embedded in Excel: 2.5 Carat
# 🔍 Searching image for: 3 Carat
# ✅ Image matches engagement ring criteria: 3 Carat
# 📷 Image embedded in Excel: 3 Carat
# 🔍 Searching image for: 4 Carat
# ✅ Image matches engagement ring criteria: 4 Carat
# 📷 Image embedded in Excel: 4 Carat
# 🔍 Searching image for: 5 Carat
# ✅ Image matches engagement ring criteria: 5 Carat
# ...

# %%
# import os
# import requests
# import openpyxl
# from google.cloud import vision
# from googleapiclient.discovery import build
# from googleapiclient.errors import HttpError
# from PIL import Image
# from io import BytesIO

# # 🔹 Ensure the image storage directory exists
# IMAGE_DIR = "Engagement_rings1"
# os.makedirs(IMAGE_DIR, exist_ok=True)

# def create_excel(file_path):
#     """Creates an Excel file with gem carat metadata in Column A."""
#     wb = openpyxl.Workbook()
#     sheet = wb.active
#     sheet.title = "EngagementRing"
    
#     # Adding headers
#     sheet.cell(row=1, column=1, value="Gem Carat")
#     for col in range(2, 12):
#         sheet.cell(row=1, column=col, value=f"Image URL {col-1}")
#     sheet.cell(row=1, column=12, value="Vision API Labels")  # Column L for labels
    
#     # Gem Carat metadata
#     gem_carat_values = [
#         "Under 1 Carat", "0.5 Carat", "1 Carat", "2 Carat", "2.5 Carat", "3 Carat",
#         "4 Carat", "5 Carat", "6 Carat", "7 Carat", "8 Carat", "9 Carat", "10 Carat",
#         "- 0.25 Carat Each Side Stone", "- Approx 0.25 Carat Smalls", "- Approx 0.5 Carat Smalls",
#         "- Approx 0.75 Carat Smalls", "- Approx 1 Carat Smalls", "- Approx 2 Carat Smalls"
#     ]
    
#     # Inserting data into the sheet
#     for idx, value in enumerate(gem_carat_values, start=2):
#         sheet.cell(row=idx, column=1, value=value)
    
#     # Save the Excel file
#     wb.save(file_path)
#     print(f"✅ Excel file created successfully: {file_path}")

# def search_image(query, api_key, cse_id):
#     """Search for an image using Google Custom Search JSON API."""
#     try:
#         service = build("customsearch", "v1", developerKey=api_key)
#         res = service.cse().list(q=query + " engagement ring", cx=cse_id, searchType="image", num=10).execute()
#         if "items" in res:
#             return [item["link"] for item in res["items"]]
#     except HttpError as e:
#         print(f"❌ Google Search API Error: {e}")
#     return []

# def analyze_image(image_url):
#     """Analyze image using Google Cloud Vision API."""
#     try:
#         client = vision.ImageAnnotatorClient()
#         image = vision.Image()
#         image.source.image_uri = image_url
#         response = client.label_detection(image=image)
#         labels = [label.description.lower() for label in response.label_annotations]
#         return labels
#     except Exception as e:
#         print(f"❌ Vision API Error: {e}")
#         return []

# def download_image(image_url):
#     """Download and return image as PIL object."""
#     try:
#         response = requests.get(image_url, timeout=10)
#         if response.status_code == 200:
#             img = Image.open(BytesIO(response.content))
#             return img
#     except Exception as e:
#         print(f"❌ Error downloading image: {e}")
#     return None

# def update_excel_with_images(file_path, api_key, cse_id):
#     """Fetch images, analyze with Vision API, filter for engagement rings, and embed images in Excel."""
#     wb = openpyxl.load_workbook(file_path)
#     sheet = wb.active

#     for row in range(2, sheet.max_row + 1):
#         metadata = sheet.cell(row, 1).value
#         if metadata:
#             existing_image_urls = [sheet.cell(row, col).value for col in range(2, 12)]  # Columns B to K
#             if not any(existing_image_urls):  # Avoid re-fetching images if already present
#                 print(f"🔍 Searching images for: {metadata}")
#                 image_urls = search_image(metadata, api_key, cse_id)
#                 if image_urls:
#                     labels = []
#                     for col, image_url in enumerate(image_urls, start=2):
#                         # Analyze image using Vision API
#                         img_labels = analyze_image(image_url)
#                         labels.append(", ".join(img_labels))

#                         # Download the image
#                         image = download_image(image_url)
#                         if image:
#                             # Save results in Excel (image URLs)
#                             sheet.cell(row, col, value=image_url)
                    
#                     # Store the Vision API labels in column L
#                     sheet.cell(row, 12, value=" | ".join(labels))
#                     print(f"✅ Images and labels for '{metadata}' added successfully!")

#     wb.save(file_path)
#     print("✅ Excel updated with engagement ring images and labels!")

# # 🔹 Google API credentials
# API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
# CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# # 🔹 Fix the file path issue
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json"  

# EXCEL_FILE = "gem_carat_data_ERImage1.xlsx"

# # 🔹 Run the functions
# create_excel(EXCEL_FILE)
# update_excel_with_images(EXCEL_FILE, API_KEY, CSE_ID)

# %%
import os
import requests
import openpyxl
from openpyxl.drawing.image import Image as ExcelImage
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "Engagement_rings1"
os.makedirs(IMAGE_DIR, exist_ok=True)

def create_excel(file_path):
    """Creates an Excel file with gem carat metadata in Column A."""
    wb = openpyxl.Workbook()
    sheet = wb.active
    sheet.title = "EngagementRing"
    
    # Adding headers
    sheet.cell(row=1, column=1, value="Gem Carat")
    for col in range(2, 12):
        sheet.cell(row=1, column=col, value=f"Image {col-1}")  # Updated for images
    sheet.cell(row=1, column=12, value="Vision API Labels")  # Column L for labels
    
    # Gem Carat metadata
    gem_carat_values = [
        "Under 1 Carat", "0.5 Carat", "1 Carat", "2 Carat", "2.5 Carat", "3 Carat",
        "4 Carat", "5 Carat", "6 Carat", "7 Carat", "8 Carat", "9 Carat", "10 Carat",
        "- 0.25 Carat Each Side Stone", "- Approx 0.25 Carat Smalls", "- Approx 0.5 Carat Smalls",
        "- Approx 0.75 Carat Smalls", "- Approx 1 Carat Smalls", "- Approx 2 Carat Smalls"
    ]
    
    # Inserting data into the sheet
    for idx, value in enumerate(gem_carat_values, start=2):
        sheet.cell(row=idx, column=1, value=value)
    
    # Save the Excel file
    wb.save(file_path)
    print(f"Excel file created successfully: {file_path}")

def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(q=query + " engagement ring", cx=cse_id, searchType="image", num=10).execute()
        if "items" in res:
            return [item["link"] for item in res["items"]]
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def update_excel_with_images(file_path, api_key, cse_id):
    """Fetch images, analyze with Vision API, filter for engagement rings, and embed images in Excel."""
    wb = openpyxl.load_workbook(file_path)
    sheet = wb.active

    for row in range(2, sheet.max_row + 1):
        metadata = sheet.cell(row, 1).value
        if metadata:
            existing_images = [sheet.cell(row, col).value for col in range(2, 12)]  # Columns B to K
            if not any(existing_images):  # Avoid re-fetching if images are already present
                print(f"Searching images for: {metadata}")
                image_urls = search_image(metadata, api_key, cse_id)
                if image_urls:
                    labels = []
                    for col, image_url in enumerate(image_urls, start=2):
                        # Generate unique file name
                        image_filename = f"{metadata.replace(' ', '_')}_{col-1}.jpg"
                        image_path = os.path.join(IMAGE_DIR, image_filename)

                        # Download and validate image
                        saved_image = download_image(image_url, image_path)

                        if saved_image:
                            print(f"Inserting image: {saved_image}")
                            try:
                                # Insert image into Excel
                                img = ExcelImage(saved_image)
                                img.width, img.height = 100, 100  # Resize images to fit cells
                                col_letter = chr(64 + col)  # Convert col number to letter (B, C, D, etc.)
                                sheet.add_image(img, f"{col_letter}{row}")
                            except Exception as e:
                                print(f"Error inserting image: {e} - File: {saved_image}")

                            # Analyze image using Vision API
                            img_labels = analyze_image(image_url)
                            labels.append(", ".join(img_labels))

                    # Store Vision API labels in column L
                    sheet.cell(row, 12, value=" | ".join(labels))
                    print(f"Images and labels for '{metadata}' added successfully!")

    wb.save(file_path)
    print("Excel updated with engagement ring images and labels!")

# Google API credentials
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json"  

# Excel file
EXCEL_FILE = "gem_carat_data_ERImage1.xlsx"

# Run the functions
create_excel(EXCEL_FILE)
update_excel_with_images(EXCEL_FILE, API_KEY, CSE_ID)
# Out:
# Excel file created successfully: gem_carat_data_ERImage1.xlsx
# Searching images for: Under 1 Carat
# Inserting image: Engagement_rings1\Under_1_Carat_1.jpg
# Inserting image: Engagement_rings1\Under_1_Carat_2.jpg
# Inserting image: Engagement_rings1\Under_1_Carat_3.jpg
# Inserting image: Engagement_rings1\Under_1_Carat_4.jpg
# Inserting image: Engagement_rings1\Under_1_Carat_5.jpg
# Inserting image: Engagement_rings1\Under_1_Carat_6.jpg
# Inserting image: Engagement_rings1\Under_1_Carat_7.jpg
# Failed to download image: https://www.zalesoutlet.com/productimages/processed/V-19416460_2_800.jpg (Status Code: 403)
# Inserting image: Engagement_rings1\Under_1_Carat_9.jpg
# Failed to download image: https://www.zalesoutlet.com/productimages/processed/V-20280665_1_800.jpg?pristine=true (Status Code: 403)
# Images and labels for 'Under 1 Carat' added successfully!
# Searching images for: 0.5 Carat
# Inserting image: Engagement_rings1\0.5_Carat_1.jpg
# ...

# %%
import os
import requests
import openpyxl
from openpyxl.drawing.image import Image as ExcelImage
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "Engagement_rings2"
os.makedirs(IMAGE_DIR, exist_ok=True)

def create_excel(file_path):
    """Creates an Excel file with gem carat metadata in Column A."""
    wb = openpyxl.Workbook()
    sheet = wb.active
    sheet.title = "EngagementRing"
    
    # Adding headers
    sheet.cell(row=1, column=1, value="Gem Carat")
    for col in range(2, 12):
        sheet.cell(row=1, column=col, value=f"Image {col-1}")
    sheet.cell(row=1, column=12, value="Vision API Labels")  # Column L for labels
    
    # Gem Carat metadata
    gem_carat_values = [
        "Under 1 Carat", "0.5 Carat", "1 Carat", "2 Carat", "2.5 Carat", "3 Carat",
        "4 Carat", "5 Carat", "6 Carat", "7 Carat", "8 Carat", "9 Carat", "10 Carat",
        "- 0.25 Carat Each Side Stone", "- Approx 0.25 Carat Smalls", "- Approx 0.5 Carat Smalls",
        "- Approx 0.75 Carat Smalls", "- Approx 1 Carat Smalls", "- Approx 2 Carat Smalls"
    ]
    
    for idx, value in enumerate(gem_carat_values, start=2):
        sheet.cell(row=idx, column=1, value=value)
    
    wb.save(file_path)
    print(f"Excel file created successfully: {file_path}")

def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        # Format query to avoid invalid characters
        formatted_query = query.replace(" ", "+").replace(".", "")  # Remove dots
        
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "+engagement+ring",
            cx=cse_id,
            searchType="image",
            num=10  # Reduced to 10 as per Google API limits
        ).execute()

        if "items" in res:
            return [item["link"] for item in res["items"]]
        else:
            print(f"No images found for query: {query}")
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def update_excel_with_images(file_path, api_key, cse_id):
    """Fetch images, analyze with Vision API, retry failed downloads, and embed images in Excel."""
    wb = openpyxl.load_workbook(file_path)
    sheet = wb.active

    for row in range(2, sheet.max_row + 1):
        metadata = sheet.cell(row, 1).value
        if metadata:
            existing_images = [sheet.cell(row, col).value for col in range(2, 12)]  # Check if images exist
            if not any(existing_images):  # Only search if no images are present
                print(f"Searching images for: {metadata}")
                image_urls = search_image(metadata, api_key, cse_id)

                if image_urls:
                    labels = []
                    col = 2  # Start inserting images from Column B (index 2)
                    max_images = 10  # Ensure max 10 images per row
                    downloaded_images = 0  # Track successfully downloaded images

                    for image_url in image_urls:
                        if downloaded_images >= max_images:
                            break  # Stop if 10 images are inserted
                        
                        # Generate unique file name
                        image_filename = f"{metadata.replace(' ', '_')}_{col-1}.jpg"
                        image_path = os.path.join(IMAGE_DIR, image_filename)

                        # Attempt to download and validate image
                        saved_image = download_image(image_url, image_path)

                        if saved_image:
                            print(f"Inserting image: {saved_image}")
                            try:
                                # Insert image into Excel
                                img = ExcelImage(saved_image)
                                img.width, img.height = 100, 100  # Resize images to fit cells
                                col_letter = chr(64 + col)  # Convert column number to letter (B, C, D, etc.)
                                sheet.add_image(img, f"{col_letter}{row}")

                                # Analyze image using Vision API
                                img_labels = analyze_image(image_url)
                                labels.append(", ".join(img_labels))

                                col += 1  # Move to the next column only if image is inserted
                                downloaded_images += 1  # Increase count of successful images
                            except Exception as e:
                                print(f"Error inserting image: {e} - File: {saved_image}")

                    # Store Vision API labels in column L
                    sheet.cell(row, 12, value=" | ".join(labels))
                    print(f"Images and labels for '{metadata}' added successfully!")

    wb.save(file_path)
    print("Excel updated with engagement ring images and labels!")

# Google API credentials (Replace these with your actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json"  

# Excel file
EXCEL_FILE = "gem_carat_data_ERImage2.xlsx"

# Run the functions
create_excel(EXCEL_FILE)
update_excel_with_images(EXCEL_FILE, API_KEY, CSE_ID)
# Out:
# Excel file created successfully: gem_carat_data_ERImage2.xlsx
# Searching images for: Under 1 Carat
# Inserting image: Engagement_rings2\Under_1_Carat_1.jpg
# Inserting image: Engagement_rings2\Under_1_Carat_2.jpg
# Inserting image: Engagement_rings2\Under_1_Carat_3.jpg
# Inserting image: Engagement_rings2\Under_1_Carat_4.jpg
# Inserting image: Engagement_rings2\Under_1_Carat_5.jpg
# Inserting image: Engagement_rings2\Under_1_Carat_6.jpg
# Inserting image: Engagement_rings2\Under_1_Carat_7.jpg
# Failed to download image: https://www.zales.com/productimages/processed/V-19416460_2_800.jpg (Status Code: 403)
# Inserting image: Engagement_rings2\Under_1_Carat_8.jpg
# Failed to download image: https://www.zalesoutlet.com/productimages/processed/V-20280665_1_800.jpg?pristine=true (Status Code: 403)
# Images and labels for 'Under 1 Carat' added successfully!
# Searching images for: 0.5 Carat
# Inserting image: Engagement_rings2\0.5_Carat_1.jpg
# ...

# %%
#Code for Gem colour
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "Gem_Color"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of gem colors for which we will fetch images
gem_colors = [
    "D-E-F Colorless", "G-H Color", "K-M Color", "Blue", "Green", "Yellow",
    "Blue-Green", "Black", "Pink", "Gray"
]
def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        # Format query to avoid invalid characters
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")  # Remove dots
        
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "+engagement+ring",
            cx=cse_id,
            searchType="image",
            num=10  # Reduced to 10 as per Google API limits
        ).execute()

        if "items" in res:
            return [item["link"] for item in res["items"]]
        else:
            print(f"No images found for query: {query}")
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each gem color."""
    for color in gem_colors:
        folder_path = os.path.join(IMAGE_DIR, color)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each gem color, using Google Custom Search and Vision API."""
    for color in gem_colors:
        print(f"Fetching images for {color}...")

        # Create subfolder for the current gem color
        color_folder = os.path.join(IMAGE_DIR, color)
        
        # Search for images related to the gem color
        image_urls = search_image(color, api_key, cse_id)

        if image_urls:
            downloaded_images = 0  # Track successfully downloaded images

            for image_url in image_urls:
                if downloaded_images >= 20:  # Stop if we have downloaded 20 images
                    break
                
                # Generate unique file name for each image
                image_filename = f"{color.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(color_folder, image_filename)

                # Attempt to download and save the image
                saved_image = download_image(image_url, image_path)

                if saved_image:
                    print(f"Image saved: {saved_image}")

                    # Analyze image with Vision API and get labels
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    
                    downloaded_images += 1
        else:
            print(f"No images found for {color}")

# Google API credentials (Replace these with your actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json"  


# Create the folder structure for Gem Color categories
create_folder_structure()

# Fetch and save images for each gem color
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for D-E-F Colorless...
# Image saved: Gem_Color\D-E-F Colorless\D-E-F_Colorless_1.jpg
# Labels for D-E-F_Colorless_1.jpg: engagement ring, diamond, natural material, metal, mineral, ring, wedding ceremony supply, pre-engagement ring, body jewelry, wedding ring
# Image saved: Gem_Color\D-E-F Colorless\D-E-F_Colorless_2.jpg
# Labels for D-E-F_Colorless_2.jpg: engagement ring, ring, gemstone, wedding ring, natural material, pre-engagement ring, diamond, silver, wedding ceremony supply, body jewelry
# Image saved: Gem_Color\D-E-F Colorless\D-E-F_Colorless_3.jpg
# Labels for D-E-F_Colorless_3.jpg: gemstone, body jewelry, engagement ring, pre-engagement ring, ring, diamond, natural material, wedding ring, wedding ceremony supply
# Image saved: Gem_Color\D-E-F Colorless\D-E-F_Colorless_4.jpg
# Labels for D-E-F_Colorless_4.jpg: white, engagement ring, ring, gemstone, natural material, diamond, crystal, silver, wedding ring, body jewelry
# ...

# %%
#Code for gem carat
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "Gem_Carat"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of gem carats for which we will fetch images (replace gem colors with carat ranges)
gem_carat = [
"Under 1 Carat",
"0.5 Carat",
"1 Carat",
"2 Carat",
"2.5 Carat",
"3 Carat",
"4 Carat",
"5 Carat",
"6 Carat",
"7 Carat",
"8 Carat",
"9 Carat",
"10 Carat",
"- 0.25 Carat Each Side Stone",
"- Approx 0.25 Carat Smalls",
"- Approx 0.5 Carat Smalls",
"- Approx 0.75 Carat Smalls",
"- Approx 1 Carat Smalls",
"- Approx 2 Carat Smalls"
]

def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        # Format query to avoid invalid characters
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")  # Remove dots
        
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "+engagement+ring",  # Include the engagement ring term
            cx=cse_id,
            searchType="image",
            num=10  # Reduced to 10 as per Google API limits
        ).execute()

        if "items" in res:
            return [item["link"] for item in res["items"]]
        else:
            print(f"No images found for query: {query}")
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each gem carat."""
    for carat in gem_carat:
        folder_path = os.path.join(IMAGE_DIR, carat)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each gem carat, using Google Custom Search and Vision API."""
    for carat in gem_carat:
        print(f"Fetching images for {carat}...")

        # Create subfolder for the current gem carat
        carat_folder = os.path.join(IMAGE_DIR, carat)
        
        # Search for images related to the gem carat
        image_urls = search_image(carat, api_key, cse_id)

        if image_urls:
            downloaded_images = 0  # Track successfully downloaded images

            for image_url in image_urls:
                if downloaded_images >= 20:  # Stop if we have downloaded 20 images
                    break
                
                # Generate unique file name for each image
                image_filename = f"{carat.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(carat_folder, image_filename)

                # Attempt to download and save the image
                saved_image = download_image(image_url, image_path)

                if saved_image:
                    print(f"Image saved: {saved_image}")

                    # Analyze image with Vision API and get labels
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    
                    downloaded_images += 1
        else:
            print(f"No images found for {carat}")

# Google API credentials (Replace these with your actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json"  

# Create the folder structure for Gem Carat categories
create_folder_structure()

# Fetch and save images for each gem carat
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for Under 1 Carat...
# Image saved: Gem_Carat\Under 1 Carat\Under_1_Carat_1.jpg
# Labels for Under_1_Carat_1.jpg: engagement ring, ring, jewellery, body jewelry, gemstone, wedding ring, wedding ceremony supply, pre-engagement ring, diamond, natural material
# Image saved: Gem_Carat\Under 1 Carat\Under_1_Carat_2.jpg
# Labels for Under_1_Carat_2.jpg: engagement ring, ring, gemstone, jewellery, body jewelry, fashion, finger, wedding ring, diamond, wedding ceremony supply
# Image saved: Gem_Carat\Under 1 Carat\Under_1_Carat_3.jpg
# Labels for Under_1_Carat_3.jpg: ring, jewellery, engagement ring, gemstone, body jewelry, diamond, natural material, pre-engagement ring, wedding ring, silver
# Image saved: Gem_Carat\Under 1 Carat\Under_1_Carat_4.jpg
# Labels for Under_1_Carat_4.jpg: engagement ring, ring, finger, body jewelry, jewellery, fashion, gemstone, wedding ring, pre-engagement ring, wedding ceremony supply
# Image saved: Gem_Carat\Under 1 Carat\Under_1_Carat_5.jpg
# ...

# %%
#Code for Gem Shape 
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "Gem_Shape"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of gem shapes
gem_shapes = [
    "Round Cut", "Oval Cut", "Princess Cut", "Emerald Cut", "Baguette Cut",
    "Pear Cut", "Marquise Cut", "Heart Cut", "Asscher Cut", "Radiant Cut",
    "Cushion Cut", "Trilliant Cut"
]

def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        # Format query to avoid invalid characters
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")  # Remove dots
        
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "+engagement+ring",  # Include engagement ring term
            cx=cse_id,
            searchType="image",
            num=10  # Limit to 10 as per Google API limits
        ).execute()

        if "items" in res:
            return [item["link"] for item in res["items"]]
        else:
            print(f"No images found for query: {query}")
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        labels = [label.description.lower() for label in response.label_annotations]
        return labels
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()  # Ensure it's a valid image
            img = Image.open(BytesIO(response.content))  # Reopen after verification
            img = img.convert("RGB")  # Convert to standard format
            img.save(save_path, format="JPEG")  # Save as JPEG
            return save_path
        else:
            print(f"Failed to download image: {image_url} (Status Code: {response.status_code})")
    except Exception as e:
        print(f"Error downloading or verifying image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each gem shape."""
    for shape in gem_shapes:
        folder_path = os.path.join(IMAGE_DIR, shape)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each gem shape, using Google Custom Search and Vision API."""
    for shape in gem_shapes:
        print(f"Fetching images for {shape}...")

        # Create subfolder for the current gem shape
        shape_folder = os.path.join(IMAGE_DIR, shape)
        
        # Search for images related to the gem shape
        image_urls = search_image(shape, api_key, cse_id)

        if image_urls:
            downloaded_images = 0  # Track successfully downloaded images

            for image_url in image_urls:
                if downloaded_images >= 20:  # Stop if we have downloaded 20 images
                    break
                
                # Generate unique file name for each image
                image_filename = f"{shape.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(shape_folder, image_filename)

                # Attempt to download and save the image
                saved_image = download_image(image_url, image_path)

                if saved_image:
                    print(f"Image saved: {saved_image}")

                    # Analyze image with Vision API and get labels
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    
                    downloaded_images += 1
        else:
            print(f"No images found for {shape}")

# Google API credentials (Replace these with your actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json"  

# Create the folder structure for Gem Shape categories
create_folder_structure()

# Fetch and save images for each gem shape
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for Round Cut...
# Image saved: Gem_Shape\Round Cut\Round_Cut_1.jpg
# Labels for Round_Cut_1.jpg: gemstone, body jewelry, engagement ring, diamond, natural material, crystal, ring, mineral, pre-engagement ring, wedding ring
# Image saved: Gem_Shape\Round Cut\Round_Cut_2.jpg
# Labels for Round_Cut_2.jpg: white, diamond, silver, natural material, engagement ring, watch, design, platinum, wedding ceremony supply, gemstone
# Image saved: Gem_Shape\Round Cut\Round_Cut_3.jpg
# Labels for Round_Cut_3.jpg: finger, jewellery, engagement ring, ring, diamond, gemstone, natural material, body jewelry, thumb, nail
# Image saved: Gem_Shape\Round Cut\Round_Cut_4.jpg
# Labels for Round_Cut_4.jpg: silver, platinum, diamond, silver, titanium, nickel, still life photography, mineral, aluminium
# Image saved: Gem_Shape\Round Cut\Round_Cut_5.jpg
# ...

# %%
#Code for Gem Setting
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "Gem_Setting"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of gem settings
gem_settings = [
    "Pave Wrap", "Solitaire", "Tension", "Starburst", "Halo", "Hidden Halo", "Double Halo",
    "Double Edge Halo", "Seamless Halo (Subtle)", "Floating Halo", "Flush Halo", "Side Stone",
    "Graduated Side Stone", "Bezel", "Vintage", "Three Stone", "Seven Stone", "Bead Set",
    "French Pave", "Pave", "Channel", "Bar", "Gypsy", "Shared Prong", "Surface Prong",
    "Scalloped", "Fishtail", "Marquise", "Cluster"
]

def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "+ring+setting",
            cx=cse_id,
            searchType="image",
            num=10
        ).execute()
        return [item["link"] for item in res.get("items", [])]
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        return [label.description.lower() for label in response.label_annotations]
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()
            img = Image.open(BytesIO(response.content))
            img = img.convert("RGB")
            img.save(save_path, format="JPEG")
            return save_path
    except Exception as e:
        print(f"Error downloading image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each gem setting."""
    for setting in gem_settings:
        folder_path = os.path.join(IMAGE_DIR, setting)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each gem setting."""
    for setting in gem_settings:
        print(f"Fetching images for {setting}...")
        setting_folder = os.path.join(IMAGE_DIR, setting)
        image_urls = search_image(setting, api_key, cse_id)
        if image_urls:
            downloaded_images = 0
            for image_url in image_urls:
                if downloaded_images >= 20:
                    break
                image_filename = f"{setting.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(setting_folder, image_filename)
                saved_image = download_image(image_url, image_path)
                if saved_image:
                    print(f"Image saved: {saved_image}")
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    downloaded_images += 1
        else:
            print(f"No images found for {setting}")

# Google API credentials (Replace with actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json"  

# Create folder structure and fetch images
create_folder_structure()
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for Pave Wrap...
# Image saved: Gem_Setting\Pave Wrap\Pave_Wrap_1.jpg
# Labels for Pave_Wrap_1.jpg: engagement ring, gemstone, diamond, crystal, ring, wedding ring, body jewelry, pre-engagement ring, natural material, mineral
# Image saved: Gem_Setting\Pave Wrap\Pave_Wrap_2.jpg
# Labels for Pave_Wrap_2.jpg: engagement ring, pre-engagement ring, ring, wedding ceremony supply, diamond, platinum
# Image saved: Gem_Setting\Pave Wrap\Pave_Wrap_3.jpg
# Labels for Pave_Wrap_3.jpg: engagement ring, ring, diamond, wedding ring, body jewelry, gemstone, pre-engagement ring, wedding ceremony supply, silver, natural material
# Image saved: Gem_Setting\Pave Wrap\Pave_Wrap_4.jpg
# Labels for Pave_Wrap_4.jpg:
# Image saved: Gem_Setting\Pave Wrap\Pave_Wrap_5.jpg
# Labels for Pave_Wrap_5.jpg: engagement ring, diamond, ring, wedding ring, body jewelry, pre-engagement ring, gemstone, wedding ceremony supply, platinum, silver
# Image saved: Gem_Setting\Pave Wrap\Pave_Wrap_6.jpg
# ...

# %%
#Code for Profile 
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "Profile"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of profiles
profiles = [
    "Modern", "Bridge Accent", "Cathedral", "Trellis", "Basket", "Low Basket", "Low Set",
    "Kite Set", "High Set", "Prong", "Tulip Set", "Invisible Gallery", "Tension", "Crown", "Swirl"
]

def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "+diamond+ring+profile",
            cx=cse_id,
            searchType="image",
            num=10
        ).execute()
        return [item["link"] for item in res.get("items", [])]
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        return [label.description.lower() for label in response.label_annotations]
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()
            img = Image.open(BytesIO(response.content))
            img = img.convert("RGB")
            img.save(save_path, format="JPEG")
            return save_path
    except Exception as e:
        print(f"Error downloading image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each profile."""
    for profile in profiles:
        folder_path = os.path.join(IMAGE_DIR, profile)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each profile."""
    for profile in profiles:
        print(f"Fetching images for {profile}...")
        profile_folder = os.path.join(IMAGE_DIR, profile)
        image_urls = search_image(profile, api_key, cse_id)
        if image_urls:
            downloaded_images = 0
            for image_url in image_urls:
                if downloaded_images >= 20:
                    break
                image_filename = f"{profile.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(profile_folder, image_filename)
                saved_image = download_image(image_url, image_path)
                if saved_image:
                    print(f"Image saved: {saved_image}")
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    downloaded_images += 1
        else:
            print(f"No images found for {profile}")

# Google API credentials (Replace with actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json"  

# Create folder structure and fetch images
create_folder_structure()
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for Modern...
# Image saved: Profile\Modern\Modern_1.jpg
# Labels for Modern_1.jpg: engagement ring, ring, diamond, natural material, pre-engagement ring, wedding ceremony supply, wedding ring, body jewelry, mineral, silver
# Image saved: Profile\Modern\Modern_2.jpg
# Labels for Modern_2.jpg: diamond, natural material, engagement ring, silver, pre-engagement ring, gemstone, platinum
# Image saved: Profile\Modern\Modern_3.jpg
# Labels for Modern_3.jpg: engagement ring, gemstone, body jewelry, diamond, ring, wedding ring, pre-engagement ring, jewellery, wedding ceremony supply, natural material
# Image saved: Profile\Modern\Modern_4.jpg
# Labels for Modern_4.jpg: silver, diamond, platinum, engagement ring, mineral, pre-engagement ring, major appliance, silver
# Image saved: Profile\Modern\Modern_5.jpg
# Labels for Modern_5.jpg: silver, spoke, platinum, hubcap
# Image saved: Profile\Modern\Modern_6.jpg
# Labels for Modern_6.jpg:
# ...

# %%
#Code for use as 
import os
import requests
from google.cloud import vision
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from PIL import Image
from io import BytesIO

# Ensure the image storage directory exists
IMAGE_DIR = "Use_As"
os.makedirs(IMAGE_DIR, exist_ok=True)

# List of jewelry types (Use As category)
use_as_types = [
    "Engagement Ring", "Earrings", "Necklace", "Bracelet", "Eternity Band", 
    "Two Piece Bridal Set", "Three Piece Bridal Set"
]

def search_image(query, api_key, cse_id):
    """Search for images using Google Custom Search JSON API."""
    try:
        formatted_query = query.replace(" ", "+").replace("-", "_").replace(".", "")
        service = build("customsearch", "v1", developerKey=api_key)
        res = service.cse().list(
            q=formatted_query + "+diamond+jewelry",
            cx=cse_id,
            searchType="image",
            num=10
        ).execute()
        return [item["link"] for item in res.get("items", [])]
    except HttpError as e:
        print(f"Google Search API Error: {e}")
    return []

def analyze_image(image_url):
    """Analyze image using Google Cloud Vision API."""
    try:
        client = vision.ImageAnnotatorClient()
        image = vision.Image()
        image.source.image_uri = image_url
        response = client.label_detection(image=image)
        return [label.description.lower() for label in response.label_annotations]
    except Exception as e:
        print(f"Vision API Error: {e}")
        return []

def download_image(image_url, save_path):
    """Download and save an image if it's valid."""
    try:
        response = requests.get(image_url, timeout=10)
        if response.status_code == 200:
            img = Image.open(BytesIO(response.content))
            img.verify()
            img = Image.open(BytesIO(response.content))
            img = img.convert("RGB")
            img.save(save_path, format="JPEG")
            return save_path
    except Exception as e:
        print(f"Error downloading image: {e} - URL: {image_url}")
    return None

def create_folder_structure():
    """Create subfolders for each jewelry type."""
    for jewelry in use_as_types:
        folder_path = os.path.join(IMAGE_DIR, jewelry)
        os.makedirs(folder_path, exist_ok=True)

def fetch_and_save_images(api_key, cse_id):
    """Fetch and save images for each jewelry type."""
    for jewelry in use_as_types:
        print(f"Fetching images for {jewelry}...")
        jewelry_folder = os.path.join(IMAGE_DIR, jewelry)
        image_urls = search_image(jewelry, api_key, cse_id)
        if image_urls:
            downloaded_images = 0
            for image_url in image_urls:
                if downloaded_images >= 20:
                    break
                image_filename = f"{jewelry.replace(' ', '_')}_{downloaded_images + 1}.jpg"
                image_path = os.path.join(jewelry_folder, image_filename)
                saved_image = download_image(image_url, image_path)
                if saved_image:
                    print(f"Image saved: {saved_image}")
                    labels = analyze_image(image_url)
                    print(f"Labels for {image_filename}: {', '.join(labels)}")
                    downloaded_images += 1
        else:
            print(f"No images found for {jewelry}")

# Google API credentials (Replace with actual credentials)
API_KEY = "AIzaSyAo5M5HXAXSkVxBzHRG0bUMRJf3RltEhJw"  # Replace with your actual API key
CSE_ID = "d63ff1141028241de"  # Replace with your actual CSE ID

# Set Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Techionik_2025\Search_functionality\jewelry-449211-b1561756ae8d.json" 

# Create folder structure and fetch images
create_folder_structure()
fetch_and_save_images(API_KEY, CSE_ID)
# Out:
# Fetching images for Engagement Ring...
# Image saved: Use_As\Engagement Ring\Engagement_Ring_1.jpg
# Labels for Engagement_Ring_1.jpg: silver
# Image saved: Use_As\Engagement Ring\Engagement_Ring_2.jpg
# Labels for Engagement_Ring_2.jpg: engagement ring, gemstone, fashion, diamond, body jewelry, pre-engagement ring, crystal, wedding ring, natural material, mineral
# Image saved: Use_As\Engagement Ring\Engagement_Ring_3.jpg
# Labels for Engagement_Ring_3.jpg: engagement ring, gemstone, jewellery, ring, wedding ceremony supply, wedding ring, body jewelry, diamond, crystal, pre-engagement ring
# Image saved: Use_As\Engagement Ring\Engagement_Ring_4.jpg
# Labels for Engagement_Ring_4.jpg: engagement ring, gemstone, body jewelry, diamond, jewellery, wedding ring, ring, pre-engagement ring, wedding ceremony supply, natural material
# Image saved: Use_As\Engagement Ring\Engagement_Ring_5.jpg
# ...
